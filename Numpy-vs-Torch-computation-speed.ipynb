# %%
# Generate two different torch objects:

import torch
x = torch.rand(1, 6400)
y = torch.rand(6400, 5000)

# %%
# Define the device to which we will store the tensor objects created above:

device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# cpu

# %%
# Register the tensor objects that were created with the device. Registering tensor objects means storing information in a device:
x, y = x.to(device), y.to(device)

# %%
# Matrix multiplication of Torch objects
# %timeit z=(x@y)
# Out:
# 10.5 ms ± 96.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Perform the same matrix multiplication, this time on NumPy arrays:

import numpy as np
x = np.random.random((1, 6400))
y = np.random.random((6400, 5000))
# %timeit z = np.matmul(x,y)
# Out:
# 22.7 ms ± 808 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
